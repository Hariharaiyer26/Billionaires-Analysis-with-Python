# %%
#Importing necessary Python Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Import Dataset

df=pd.read_csv("Forbes Billionaires 2023.csv")

# %%
df #This will print dataset
# Out:
#                                      Name NetWorth  \
# 0                Bernard Arnault & Family   $211 B
# 1                               Elon Musk   $180 B
# 2                              Jeff Bezos   $114 B
# 3                           Larry Ellison   $107 B
# 4                          Warren Buffett   $106 B
# 5                              Bill Gates   $104 B
# 6                       Michael Bloomberg    $95 B
# 7               Carlos Slim Helu & Family    $93 B
# 8                           Mukesh Ambani    $83 B
# 9                           Steve Ballmer    $81 B
# 10  Francoise Bettencourt Meyers & Family    $81 B
# 11                             Larry Page    $79 B
# 12                         Amancio Ortega    $77 B
# 13                            Sergey Brin    $76 B
# 14                         Zhong Shanshan    $68 B
# 15                        Mark Zuckerberg    $64 B
# 16                  Charles Koch & Family    $59 B
# ...

# %%
df.head() #This will print the first five records
# Out:
#                        Name NetWorth              Source        Country  Rank  \
# 0  Bernard Arnault & Family   $211 B                LVMH         France     1
# 1                 Elon Musk   $180 B       Tesla, SpaceX  United States     2
# 2                Jeff Bezos   $114 B              Amazon  United States     3
# 3             Larry Ellison   $107 B              Oracle  United States     4
# 4            Warren Buffett   $106 B  Berkshire Hathaway  United States     5
#
#    Age               Industry Gender
# 0   74       Fashion & Retail   Male
# 1   51             Automotive   Male
# 2   59             Technology   Male
# 3   78             Technology   Male
# 4   92  Finance & Investments   Male

# %%
df.tail() #This will print the last five records
# Out:
#                         Name NetWorth                Source        Country  \
# 45  Reinhold Wuerth & Family    $30 B             Fasteners        Germany
# 46              Lee Shau Kee    $30 B           Real estate      Hong Kong
# 47                 Jeff Yass    $29 B  Trading, Investments  United States
# 48                Jim Simons    $28 B           Hedge funds  United States
# 49        Stephen Schwarzman    $28 B           Investments  United States
#
#     Rank  Age               Industry Gender
# 45    46   87          Manufacturing   Male
# 46    47   95            Real Estate   Male
# 47    48   64  Finance & Investments   Male
# 48    49   84  Finance & Investments   Male
# 49    50   76  Finance & Investments   Male

# %%
# INSIGHTS

Total Rows = 50
Total Columns = 8

No null values are present in the dataset
Datatype of NetWorth is object because of '$' and 'B' signs that was used duirng data cleansing process

# %%
# The NetWorth column in this dataset has a '$' sign at the beginning of Net worth and 'B' at the end. So we need to remove these signs and convert the NetWorth column to float

df["NetWorth"]= df["NetWorth"].str.strip("$")
df["NetWorth"]= df["NetWorth"].str.strip("B")
df["NetWorth"]= df["NetWorth"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 # The NetWorth column in this dataset has a '$' sign at the beginning of Net worth and 'B' at the end. So we need to remove these signs and convert the NetWorth column to float
# ----> 3 df["NetWorth"]= df["NetWorth"].str.strip("$")
#       4 df["NetWorth"]= df["NetWorth"].str.strip("B")
#       5 df["NetWorth"]= df["NetWorth"].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# ...

# %%
df.head(10)
# Out:
#                         Name  NetWorth              Source        Country  \
# 0   Bernard Arnault & Family     211.0                LVMH         France
# 1                  Elon Musk     180.0       Tesla, SpaceX  United States
# 2                 Jeff Bezos     114.0              Amazon  United States
# 3              Larry Ellison     107.0              Oracle  United States
# 4             Warren Buffett     106.0  Berkshire Hathaway  United States
# 5                 Bill Gates     104.0           Microsoft  United States
# 6          Michael Bloomberg      95.0        Bloomberg LP  United States
# 7  Carlos Slim Helu & Family      93.0             Telecom         Mexico
# 8              Mukesh Ambani      83.0         Diversified          India
# 9              Steve Ballmer      81.0           Microsoft  United States
#
#    Rank  Age               Industry Gender
# 0     1   74       Fashion & Retail   Male
# 1     2   51             Automotive   Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      50 non-null     object
#  1   NetWorth  50 non-null     float64
#  2   Source    50 non-null     object
#  3   Country   50 non-null     object
#  4   Rank      50 non-null     int64
#  5   Age       50 non-null     int64
#  6   Industry  50 non-null     object
#  7   Gender    50 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
df = df.head(10)
plt.figure(figsize=(20, 10))
sns.histplot(x="Name", hue="NetWorth", data=df)
plt.show()

# %%
a=df["Industry"].value_counts().head()
a
# Out:
# Industry
# Technology               4
# Fashion & Retail         1
# Automotive               1
# Finance & Investments    1
# Media & Entertainment    1
# Name: count, dtype: int64

# %%
Index=a.index
Index
# Out:
# Index(['Technology', 'Fashion & Retail', 'Automotive', 'Finance & Investments',
#        'Media & Entertainment'],
#       dtype='object', name='Industry')

# %%
Values=a.values
Values
# Out:
# array([4, 1, 1, 1, 1], dtype=int64)

# %%
plt.figure(figsize=(5, 5))
plt.pie(Values, labels=Index, colors=["ivory", "lavenderblush", "lightcoral", "darkcyan", "slategrey"])
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.title("Top Five Industry to have a Billionaire", fontsize=20)
plt.show()

# %%
#Top five countries to have a millionaire

a=df["Country"].value_counts().head()
Index=a.index
Values=a.values
plt.figure(figsize=(5, 5))
plt.pie(Values, labels=Index, colors=["steelblue", "hotpink", "lightcoral", "turquoise", "darksalmon"])
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.title("Top Five Countries to have a Billionaire", fontsize=20)
plt.show()
